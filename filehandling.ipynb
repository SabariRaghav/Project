# %%
with open('example.txt','r') as file:
    c=file.read()
    print(c)
# Out:
# hi hello
# python programming

# %%
with open('example.txt','w') as file:
    file.write('tenkasi\n')
    file.write('chennai\n')

# %%
with open('example.txt','a') as file:
    file.write('tenkasi\n')
    file.write('chennai\n')

# %%
lst=["apple\n","orange\n","mango\n"]
with open('example.txt','w') as file:
    file.writelines(lst)

# %%
with open('example.txt','r') as file:
    c=file.read()
with open('example1.txt','w') as file1:
    file1.write(c)

# %%
with open('example.txt','w+') as file:
    file.write("Watermelon")
    file.seek(0)
    c=file.read()
    print(c)
# Out:
# Watermelon

# %%
import os 
cwd=os.getcwd()
print(cwd)
# Out:
# d:\Python

# %%
n='package'
os.mkdir(n)

# %%
items=os.listdir()
print(items)
# Out:
# ['Basic.ipynb', 'example.txt', 'example1.txt', 'filehandling.ipynb', 'package']

# %%
try:
    file1=open('example2.txt','r') 
    c=file1.read()
    print(c)
except FileNotFoundError as ex:
    print(ex)
# Out:
# [Errno 2] No such file or directory: 'example2.txt'
